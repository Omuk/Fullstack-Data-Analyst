# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
sns.set(style='white', palette='muted', color_codes=True)
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import plotly.express as px

# %% [markdown]
# Import file and make it a data frame

# %%
df = pd.read_csv(r'C:\Data-Analysis\Covid_Impact\covid_sur.csv')

# %%
data = pd.DataFrame(df)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82422585 entries, 0 to 82422584
# Data columns (total 12 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   cdc_case_earliest_dt     object
#  1   cdc_report_dt            object
#  2   pos_spec_dt              object
#  3   onset_dt                 object
#  4   current_status           object
#  5   sex                      object
#  6   age_group                object
#  7   race_ethnicity_combined  object
#  8   hosp_yn                  object
#  9   icu_yn                   object
#  10  death_yn                 object
#  11  medcond_yn               object
# dtypes: object(12)
# memory usage: 7.4+ GB

# %%
data.head(10)
# Out:
#   cdc_case_earliest_dt  cdc_report_dt pos_spec_dt    onset_dt  \
# 0            2022/01/22    2022/01/24  2022/01/22         NaN
# 1            2021/01/24    2021/01/24  2021/01/27  2021/01/24
# 2            2021/09/12    2021/09/27  2021/09/12         NaN
# 3            2021/04/17    2021/07/10  2021/04/19  2021/04/17
# 4            2020/12/04    2021/02/26  2020/12/04  2020/12/04
# 5            2021/11/04    2021/11/04  2021/11/07  2021/11/04
# 6            2022/01/04    2022/01/04         NaN         NaN
# 7            2021/12/22    2022/01/16  2021/12/27  2021/12/22
# 8            2020/10/29    2020/11/11         NaN  2020/10/29
# 9            2022/02/07    2022/02/07  2022/02/07         NaN
#
#               current_status   sex      age_group race_ethnicity_combined  \
# 0  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 1  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 2  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 3  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 4  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 5  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 6  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 7              Probable Case  Male  20 - 29 Years                 Unknown
# 8  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
# 9  Laboratory-confirmed case  Male  20 - 29 Years                 Unknown
#
#    hosp_yn   icu_yn death_yn medcond_yn
# 0       No  Missing  Unknown    Missing
# 1       No  Unknown       No    Unknown
# 2  Missing  Missing  Unknown    Missing
# 3       No  Missing  Missing         No
# 4       No       No       No    Missing
# 5       No  Unknown       No        Yes
# 6  Missing  Missing  Missing    Missing
# 7  Missing  Missing  Missing    Missing
# 8  Missing  Missing  Missing    Missing
# 9       No  Unknown       No    Unknown

# %%
mis_val = data.isnull().sum() * 100/len(data)

# %%
mis_val.sort_values(ascending=False)
# Out:
# onset_dt                   60.867211
# pos_spec_dt                59.519402
# cdc_report_dt               9.088815
# age_group                   0.000092
# sex                         0.000012
# race_ethnicity_combined     0.000005
# cdc_case_earliest_dt        0.000000
# current_status              0.000000
# hosp_yn                     0.000000
# icu_yn                      0.000000
# death_yn                    0.000000
# medcond_yn                  0.000000
# dtype: float64

# %%
data.drop(columns=['onset_dt', 'pos_spec_dt', 'cdc_report_dt'], inplace=True)

# %% [markdown]
# Now run the missing values again code

# %%
mis_val = data.isnull().sum() * 100/len(data)
mis_val.sort_values(ascending=False)
# Out:
# age_group                  0.000092
# sex                        0.000012
# race_ethnicity_combined    0.000005
# cdc_case_earliest_dt       0.000000
# current_status             0.000000
# hosp_yn                    0.000000
# icu_yn                     0.000000
# death_yn                   0.000000
# medcond_yn                 0.000000
# dtype: float64

# %% [markdown]
# Because covid affects each age group, sex and ethnicity separately, I will not impute the data, however am going to drop the missing rows

# %%
data = data.dropna(axis=0, how='any')

# %%
data.head(20)
# Out:
#    cdc_case_earliest_dt              current_status   sex      age_group  \
# 0             2022/01/22  Laboratory-confirmed case  Male  20 - 29 Years
# 1             2021/01/24  Laboratory-confirmed case  Male  20 - 29 Years
# 2             2021/09/12  Laboratory-confirmed case  Male  20 - 29 Years
# 3             2021/04/17  Laboratory-confirmed case  Male  20 - 29 Years
# 4             2020/12/04  Laboratory-confirmed case  Male  20 - 29 Years
# 5             2021/11/04  Laboratory-confirmed case  Male  20 - 29 Years
# 6             2022/01/04  Laboratory-confirmed case  Male  20 - 29 Years
# 7             2021/12/22              Probable Case  Male  20 - 29 Years
# 8             2020/10/29  Laboratory-confirmed case  Male  20 - 29 Years
# 9             2022/02/07  Laboratory-confirmed case  Male  20 - 29 Years
# 10            2020/11/23  Laboratory-confirmed case  Male  20 - 29 Years
# 11            2020/11/28  Laboratory-confirmed case  Male  20 - 29 Years
# 12            2020/10/30  Laboratory-confirmed case  Male  20 - 29 Years
# 13            2021/04/02  Laboratory-confirmed case  Male  20 - 29 Years
# 14            2022/07/06              Probable Case  Male  20 - 29 Years
# 15            2021/02/20              Probable Case  Male  20 - 29 Years
# 16            2021/12/30  Laboratory-confirmed case  Male  20 - 29 Years
# 17            2022/05/09  Laboratory-confirmed case  Male  20 - 29 Years
# 18            2020/11/22  Laboratory-confirmed case  Male  20 - 29 Years
# 19            2021/12/28  Laboratory-confirmed case  Male  20 - 29 Years
#
#    race_ethnicity_combined  hosp_yn   icu_yn death_yn medcond_yn
# 0                  Unknown       No  Missing  Unknown    Missing
# 1                  Unknown       No  Unknown       No    Unknown
# 2                  Unknown  Missing  Missing  Unknown    Missing
# 3                  Unknown       No  Missing  Missing         No
# 4                  Unknown       No       No       No    Missing
# 5                  Unknown       No  Unknown       No        Yes
# 6                  Unknown  Missing  Missing  Missing    Missing
# 7                  Unknown  Missing  Missing  Missing    Missing
# 8                  Unknown  Missing  Missing  Missing    Missing
# 9                  Unknown       No  Unknown       No    Unknown
# 10                 Unknown       No  Missing  Unknown         No
# 11                 Unknown       No  Missing       No    Missing
# 12                 Unknown  Missing  Missing       No    Missing
# 13                 Unknown  Unknown  Missing  Missing    Missing
# 14                 Unknown  Missing  Missing  Missing    Missing
# 15                 Unknown  Unknown  Unknown       No    Unknown
# 16                 Unknown       No  Missing       No    Missing
# 17                 Unknown  Missing  Missing  Missing    Missing
# 18                 Unknown  Unknown  Missing  Missing    Missing
# 19                 Unknown  Unknown  Unknown       No    Unknown

# %% [markdown]
# Next I am going to replace all missing values with NaN

# %%
for col in data.columns:
    data[col].replace({'Missing':np.nan},inplace=True)

# %% [markdown]
# Now run the Head again

# %%
data.head(20)
# Out:
#    cdc_case_earliest_dt              current_status   sex      age_group  \
# 0             2022/01/22  Laboratory-confirmed case  Male  20 - 29 Years
# 1             2021/01/24  Laboratory-confirmed case  Male  20 - 29 Years
# 2             2021/09/12  Laboratory-confirmed case  Male  20 - 29 Years
# 3             2021/04/17  Laboratory-confirmed case  Male  20 - 29 Years
# 4             2020/12/04  Laboratory-confirmed case  Male  20 - 29 Years
# 5             2021/11/04  Laboratory-confirmed case  Male  20 - 29 Years
# 6             2022/01/04  Laboratory-confirmed case  Male  20 - 29 Years
# 7             2021/12/22              Probable Case  Male  20 - 29 Years
# 8             2020/10/29  Laboratory-confirmed case  Male  20 - 29 Years
# 9             2022/02/07  Laboratory-confirmed case  Male  20 - 29 Years
# 10            2020/11/23  Laboratory-confirmed case  Male  20 - 29 Years
# 11            2020/11/28  Laboratory-confirmed case  Male  20 - 29 Years
# 12            2020/10/30  Laboratory-confirmed case  Male  20 - 29 Years
# 13            2021/04/02  Laboratory-confirmed case  Male  20 - 29 Years
# 14            2022/07/06              Probable Case  Male  20 - 29 Years
# 15            2021/02/20              Probable Case  Male  20 - 29 Years
# 16            2021/12/30  Laboratory-confirmed case  Male  20 - 29 Years
# 17            2022/05/09  Laboratory-confirmed case  Male  20 - 29 Years
# 18            2020/11/22  Laboratory-confirmed case  Male  20 - 29 Years
# 19            2021/12/28  Laboratory-confirmed case  Male  20 - 29 Years
#
#    race_ethnicity_combined  hosp_yn   icu_yn death_yn medcond_yn
# 0                  Unknown       No      NaN  Unknown        NaN
# 1                  Unknown       No  Unknown       No    Unknown
# 2                  Unknown      NaN      NaN  Unknown        NaN
# 3                  Unknown       No      NaN      NaN         No
# 4                  Unknown       No       No       No        NaN
# 5                  Unknown       No  Unknown       No        Yes
# 6                  Unknown      NaN      NaN      NaN        NaN
# 7                  Unknown      NaN      NaN      NaN        NaN
# 8                  Unknown      NaN      NaN      NaN        NaN
# 9                  Unknown       No  Unknown       No    Unknown
# 10                 Unknown       No      NaN  Unknown         No
# 11                 Unknown       No      NaN       No        NaN
# 12                 Unknown      NaN      NaN       No        NaN
# 13                 Unknown  Unknown      NaN      NaN        NaN
# 14                 Unknown      NaN      NaN      NaN        NaN
# 15                 Unknown  Unknown  Unknown       No    Unknown
# 16                 Unknown       No      NaN       No        NaN
# 17                 Unknown      NaN      NaN      NaN        NaN
# 18                 Unknown  Unknown      NaN      NaN        NaN
# 19                 Unknown  Unknown  Unknown       No    Unknown

# %%
mis_valnew = data.isnull().sum() * 100/len(data)

# %%
mis_valnew.sort_values(ascending=False)
# Out:
# icu_yn                     86.659364
# medcond_yn                 81.900519
# death_yn                   52.986488
# hosp_yn                    47.618121
# race_ethnicity_combined     2.700369
# age_group                   0.938412
# sex                         0.523784
# cdc_case_earliest_dt        0.000000
# current_status              0.000000
# dtype: float64

# %% [markdown]
# the icu_yn is missing a lot of data(86%) create a variable that will look at which race and age group is missing all this data. This is everything

# %%
icu_miss = data.copy

# %% [markdown]
# Save this copy as icu_mising data

# %% [markdown]
# I am going to drop the 6%, but create another variable with the six, this new variable is called 'missing_alot' and will have 14% of total collected data---- 14% is whats available for icu_yn for all

# %%
missing_alot = data.dropna(axis=0, how='any')

# %% [markdown]
# Now this is the current data in the process

# %%
data = data.drop(columns=['icu_yn', 'medcond_yn', 'death_yn', 'hosp_yn'])

# %%
new_datmis = data.isnull().sum() * 100/len(data)

# %%
data.head(20)
# Out:
#    cdc_case_earliest_dt              current_status   sex      age_group  \
# 0             2022/01/22  Laboratory-confirmed case  Male  20 - 29 Years
# 1             2021/01/24  Laboratory-confirmed case  Male  20 - 29 Years
# 2             2021/09/12  Laboratory-confirmed case  Male  20 - 29 Years
# 3             2021/04/17  Laboratory-confirmed case  Male  20 - 29 Years
# 4             2020/12/04  Laboratory-confirmed case  Male  20 - 29 Years
# 5             2021/11/04  Laboratory-confirmed case  Male  20 - 29 Years
# 6             2022/01/04  Laboratory-confirmed case  Male  20 - 29 Years
# 7             2021/12/22              Probable Case  Male  20 - 29 Years
# 8             2020/10/29  Laboratory-confirmed case  Male  20 - 29 Years
# 9             2022/02/07  Laboratory-confirmed case  Male  20 - 29 Years
# 10            2020/11/23  Laboratory-confirmed case  Male  20 - 29 Years
# 11            2020/11/28  Laboratory-confirmed case  Male  20 - 29 Years
# 12            2020/10/30  Laboratory-confirmed case  Male  20 - 29 Years
# 13            2021/04/02  Laboratory-confirmed case  Male  20 - 29 Years
# 14            2022/07/06              Probable Case  Male  20 - 29 Years
# 15            2021/02/20              Probable Case  Male  20 - 29 Years
# 16            2021/12/30  Laboratory-confirmed case  Male  20 - 29 Years
# 17            2022/05/09  Laboratory-confirmed case  Male  20 - 29 Years
# 18            2020/11/22  Laboratory-confirmed case  Male  20 - 29 Years
# 19            2021/12/28  Laboratory-confirmed case  Male  20 - 29 Years
#
#    race_ethnicity_combined
# 0                  Unknown
# 1                  Unknown
# 2                  Unknown
# 3                  Unknown
# 4                  Unknown
# 5                  Unknown
# 6                  Unknown
# 7                  Unknown
# 8                  Unknown
# 9                  Unknown
# 10                 Unknown
# 11                 Unknown
# 12                 Unknown
# 13                 Unknown
# 14                 Unknown
# 15                 Unknown
# 16                 Unknown
# 17                 Unknown
# 18                 Unknown
# 19                 Unknown

# %%
check_miss = data.isin(['']).sum()

# %%
check_miss
# Out:
# cdc_case_earliest_dt       0
# current_status             0
# sex                        0
# age_group                  0
# race_ethnicity_combined    0
# dtype: int64

# %%
for col in data.columns:
    data[col].replace({'':np.nan},inplace=True)

# %%
new_dat = data.isnull().sum() * 100/len(data)

# %%
data.to_csv('C:\Data-Analysis\Covid_Impact\cleaned_covid_sur.csv')

# %% [markdown]
# C:\Data-Analysis\Covid_Impact\covid_sur.csv
