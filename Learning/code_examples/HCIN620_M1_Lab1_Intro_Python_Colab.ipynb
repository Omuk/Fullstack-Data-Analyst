# %% [markdown]
# #$\color{brown}{\text{HCIN 620 Lab 1 Introduction to Python in Google Colaboratory }}$
# In this lab, we are going to learn the basic workflow of machine learning. The authors developed this 4 step strategy to provide consistency across all of the labs. When evaluating other Python notebooks outside this course, you'll see similar steps that may vary a little in naming conventions, sequence and grouping.
#
# *   Step 1: Environment Setup
# *   Step 2: Data Cleaning
# *   Step 3: Exploratory Data Analysis
# *   Step 4: Build & Evaluate the Models
#
# First we need to learn the basics of the Google Colab environment. We can either add code or text using the buttons in the upper left of the screen. The **+ Code** button creates a shaded section where we can input Python commands. The **+Text** button creates a white area for text.
#
# Note that **CTRL Z** is an important editing command to undo your typing if you make mistakes.
#
# The code cells can be executed by either using **Shift + Enter** while the mouse is inside the cells or just simply hitting the **run icon** on the left side of the cell.
#
# Side Note: You can change the theme of Colab by clicking on the wheel icon on the upper right corner and choosing a dark theme.
#
# Notebook by Reza Afra, Ph.D. and Barbara Berkovich, Ph.D., M.A.
# Last update 12/27/2020

# %% [markdown]
# # **Step 1 Environment Setup**
#
# **Importing Libraries**
#
# Data scientist use a variety of libraries to perform their tasks expeditiously.
# Libraries are the codes written by others and advailable to use to use so
# that we don't have to code everything up from scratch. Below you will find a
# few common libraries for plotting, manipulating data, performing statistical
# inference etc. The first step is to *import* these libraries. That is done
# using the command "import" in Python. An altertative is to only import a
# subset of a library. For example, in the below cell I have only imported parts of sklearn library. You can learn more about each term by hovering your mouse
# over the term. A window will show up detailed description of each item.
#
# **Run the code cell below (either press Shift+Enter or press the Run button.)**

# %%
import pandas as pd              # a powerful data manipulation library
import io                        # helps with input/output of csv files 
import matplotlib.pyplot as plt  # a library to plot nice graphs. plt is just a short alias
plt.style.use('ggplot')          # just makes plots pretty

print('Import 1 complete')

# %% [markdown]
# **Question 1** Edit this text box by typing the words that appeared below the grey box.
#
# **Answer 1**     [Type answer here]

# %% [markdown]
# If you didn't see any words you must run the code cell above until you do.
#
# We will be running our Python program in small steps which must be processed sequentially from top to bottom. Sometimes if there's a problem in the middle of the program, you'll want to start over. Let's practice that now.
#
# Click **Edit** on the main menu and clear outputs.

# %% [markdown]
# **Question 2** Edit this text to describe what happened to the words in Question 1 when you cleared the outputs.
#
# **Answer 2**     [Type answer here]

# %% [markdown]
# Rerun the Import 1 code, and go on to Step 2.

# %% [markdown]
# # **Step 2: Data Cleaning**
#
# We include uploading the data as the first part of the data cleaning step.
# Even though your data is local on your machine, you need to upload it into the Colab Runtime Environment (RTE).
# To load data, **click on the folder icon on the left margin**. Immediately to the right of the magnifying glass, there's an upload icon (a paper with up arrow). If you over over the upload icon, it says **Upload to session storage**.
#
# **Use the upload icon to upload data-lab-1&2-diabetes.csv.**

# %% [markdown]
# **Question 3** What subfolder appears in the file list above data-lab-1&2-diabetes.csv
#
# **Answer 3**     [Type answer here]

# %% [markdown]
# The next step is to read the data, so that we can begin to review and clean it.
# To do that we use **read_csv** command from Pandas library to read our .csv file. Then we copy it to a pandas data frame which is an array format with a fixed number rows and columns. Lastly, we use the data.head() command to confirm that the data has been read.
#
# **Run the code cell to read the csv file.**

# %%
df = pd.read_csv('data-lab-1&2-diabetes.csv')
data = df.copy()
data.head()

# %% [markdown]
# **Question 4** How many rows and columns are displayed?
#
# **Answer 4**     [Number of Rows], [Number of Columns]

# %% [markdown]
# **Question 5** If this was a more complex dataset and we wanted to clean the data before use, what kinds of things might we test for?
#
# **Answer 5**     [Type answer here]

# %% [markdown]
# #**Step 3: Exploratory Data Analysis (EDA)**
#
# Now that we've had our first glance at the data, we can begin the Exploratory Data Analysis. Notice that the first column is just the row indices starting from 0. That is not a variable. The dataset consist of measurements of Glucose level, systolic blood pressure (BP_SYS), body mass index (BMI) , age (AGE), and whether or not the patient is on insulin (Insulin_YN). The last column is coded as 0 meaning the patient is on insulin and 1 meaning they are not.
#
# The **head()** command show us 5 rows by default.
#
# **Change the number inside the parentheses to 10, and run the head command again.**

# %%
data.head(10)

# %% [markdown]
# **Question 6** How many rows were displayed this time?
#
# **Answer 6**     [Type answer here]

# %% [markdown]
# **Exploration**  take a few minutes now to scroll througth the official "[10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html#min)" tutorial.
#
# Find the syntax for the .head() command on input line 13, and identify the next 3 commands in the Viewing data section of the tutorial.
#
# **Question 7** Type and run the code to display the dataset tail.

# %%
## Answer 7: Edit this code cell 

data.tail()

# %% [markdown]
# **Question 8** How many rows are in this dataset?
#
# **Answer 8**     [Type answer here]

# %% [markdown]
# **Please check that answer by running the shape command now.**

# %%
data.shape

# %% [markdown]
# As you can see this dataset has 768 rows (remember that the row indices start from 0).
#
# **Question 9** Why is the last line number from the tail command less than the number of rows?
#
# **Answer 9** [Type answer here]

# %% [markdown]
# Let's now quicky get some basic statistics of our data.
#
# **Run the code below to find the mean, median and standard deviation of each variable. **

# %%
data.mean()

# %%
data.median()

# %%
data.std()

# %% [markdown]
# **Question 10** List the mean, median, and standard deviation of Insulin_YN. Keeping in mind that _YN is a suffix commonly used to denote boolean data (0= no, and 1=y), can you make any conclusions about Insulin_YN from the descriptive statistics of mean, median, and standard deviation?
#
# **Question 10 Answer** [mean], [median], [ std deviation]
#                        [conclusions about Insulin_YN]

# %% [markdown]
# **Histogram** Run the code below too plot a histogram of the glucose levels.

# %%
plt.hist(data["Glucose"], bins=20); # distribution of Glucose level. 
plt.xlabel("Glucose")
plt.ylabel("Count")
plt.savefig("glucose-distribution.png")

# %% [markdown]
# Notice that this code section created a new image file called glucose-distribution.png. That's handy, right?
#
# **Question 11** What information can you glean from the distribution? Look up the clinical meaning of blood glucose levels to inform  your answer.
#
#
# **Answer 11**  [Type answer here]

# %% [markdown]
# **Scatter Matrix** A very useful plot for EDA is the scatter matrix, which is located at `pd.plotting` sub-library.

# %%
pd.plotting.scatter_matrix(data);

# %% [markdown]
# **Question 12** Describe any insights  you might draw from this plot. Consider skewed distributions, outliers categorical data, outliers, or anything you think might be interesting.
#
#
#
# **Answer 12**  [Type answer here]

# %% [markdown]
# **Have Fun**  Use any of your resources to try out one or more new python commands on your own. Just pop in a new code cell, and run it. If it throws an error, see if you can figure out what the problem is. Don't worry, you can't break anything. Add comments to the code preceded by a hash sign (#). Add a new text cell to explain what you learned.

# %% [markdown]
# #**Step 4: Build the Models and Evaluate**
#
# Since you're just getting your feet wet, that's the end of the questions for this lab.
#
# You don't need to know all the commands of Pandas for this course. Even professional data scientists look up how to do things in libraries every single day. The best resources are https://stackoverflow.com/ where you can post questions. (Before you post please read the posting guidlines!)

# %% [markdown]
# #**Turn it in**
#
# When all the questions are complete, and the code has been run, do a **File>Save**. Then print the notebook (**File>Print>As PDF**) and turn it in to Blackboard. Use the naming convention: HCIN620_Lab1_[Name].pdf
